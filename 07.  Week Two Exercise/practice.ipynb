# %%
# Variables and Data Structures

age = 45
height = 1.75
name = "John Doe"
symptoms = ['fever', 'cough', 'headache']
patient_info = {
    'ID':1,
    'Name': 'John Doe',
    'BMI': 23.5
}

#Print variable type and value
print(f"Age {age} and it's Type is {type(age)} ")
print(f"Height {height} and it's Type is {type(height)} ")
print(f"Symptoms {symptoms} and it's Type is {type(symptoms)} ")
print(f"Patient info {patient_info} and it's Type is {type(patient_info)} ")

patient_info['Age'] = 45
print(f"Patient with added Age is {patient_info}")
# Out:
# Age 45 and it's Type is <class 'int'>
# Height 1.75 and it's Type is <class 'float'>
# Symptoms ['fever', 'cough', 'headache'] and it's Type is <class 'list'>
# Patient info {'ID': 1, 'Name': 'John Doe', 'BMI': 23.5} and it's Type is <class 'dict'>
# Patient with added Age is {'ID': 1, 'Name': 'John Doe', 'BMI': 23.5, 'Age': 45}

# %%
# Operators in Python
# Solution for problem 2
A = 120
B = 30
C = 70
D = 20
E = 5
F = 2
G = 1
H = 10
I = 25

risk_score = ((A + B) * (C - D) + E) / (F * (G + H) - I)
print("Risk Score:", risk_score)
# Out:
# Risk Score: -2501.6666666666665

# %%
# Iteration in Python
patient_data = [(65, 100), (45,90), (72, 150), (51,105), (40, 85)]


# glucose_age_over_50 = []
# for age, glucose in patient_data:
#     if age > 50:
#         glucose_age_over_50.append(glucose)


# averange_glucose_level_50 = sum(glucose_age_over_50)/len(glucose_age_over_50)
# print(f"Average glucose level for patient over 50 is {round((averange_glucose_level_50))} ")

#Alternative

averange_glucose_level_50 = [glucose for age, glucose in patient_data if age > 50]
# print(averange_glucose_level_50)

averange_glucose_level_50 = sum(glucose_age_over_50)/len(glucose_age_over_50)
print(f"Average glucose level for patient over 50 is {round((averange_glucose_level_50))} ")
# Out:
# Average glucose level for patient over 50 is 118

# %%
# Problem 4: Iteration in Python
glucose_levels = [85, 90, 78, 88, 75, 85, 95, 89, 84]

# number_patient_with_gl_90 = len([gl for gl in glucose_levels if gl == 90])
# print(f"Numer of patients with glucose level 90 is {number_patient_with_gl_90}")

#Alternative
count = 0

for gl in glucose_levels:
    if gl == 90:
        print(gl)
        count += 1


print(f"Numer of patients with glucose level 90 is {count}")
# Out:
# Numer of patients with glucose level 90 is 1
# 90
# Numer of patients with glucose level 90 is 1

# %%
# Proble 5 : Data Structures in Python
patient_info = [
    {'ID': 1, 'Name': 'Alice','BMI': 22.4},
    {'ID': 2, 'Name': 'Bob','BMI': 27.1},
    {'ID': 3, 'Name': 'Charlie','BMI': 24.0},
]

patient_info.append({'ID': 4, 'Name': 'Joseph','BMI': 30.0})
# print(f"Display patient_info list after adding a new patient {patient_info}")

#remove patient info based on id
patient_info.pop(patient_info[1]['ID'] == 2)

# Update BMI based on patient ID
patient_info[1]['BMI'] = 80

print(patient_info)
# Out:
# [{'ID': 1, 'Name': 'Alice', 'BMI': 22.4}, {'ID': 3, 'Name': 'Charlie', 'BMI': 80}, {'ID': 4, 'Name': 'Joseph', 'BMI': 30.0}]

# %%
# Problem 6: Function in Python
def calculate_bmi(weight, height):
    bmi = weight / (height**2)
    return bmi

def categorize_bmi(bmi):
    if bmi < 18.5:
        return "Underweight"
    elif 18.5 <= bmi < 24.9:
        return "Normal"
    elif 25 <= bmi < 29.9:
        return "Overweight"
    else:
        return "Obese"

weight = 70
height = 1.75
print(f"BMI: {calculate_bmi(weight,height)}, Category: {categorize_bmi(calculate_bmi(weight,height))}")
# Out:
# BMI: 22.857142857142858, Category: Normal

# %%
# Probelm 7: Testing and Error Handing in Python

def safe_divide(numerator, denominator):
    try:
        result = numerator /denominator
        
    except ZeroDivisionError:
        print('Error: Division by zero is no allowed.')
        return None

    else:
        return result



print('Result 1:', safe_divide(10,2))
# print('Result 1:', safe_divide(10,0))
# Out:
# Result 1: 5.0

# %%
# Problem 8: Testing and Handing Error in Python

def divide_numbers(a,b):
    try:
        return a/b
    except ZeroDivisionError:
        return "Division by zero is not allowed"
    except TypeError:
        return "Input must be numbers"



# Example usage
result1 = divide_numbers(10,2)
result2 = divide_numbers(10,0)
result3 = divide_numbers(10,"five")b

print(result1)
print(result2)
print(result3)
# Out:
# 5.0
# Division by zero is not allowed
# Input must be numbers

# %%
# Problem 8: Testing and Handing Errors
def divide_number(a,b):
    try:
        if not (isinstance(a,(int,float)) and isinstance(b, (int,float))):
            raise TypeError("Error: Input must be numbers")
        if b == 0:
            raise ZeroDivisionError("Error: Division by zero is not allowed")
        return a/b
    except (TypeError, ZeroDivisionError) as e:
        return e

print(divide_number(10,2))   
print(divide_number('a',2))   
print(divide_number(10,0))
# Out:
# 5.0
# Error: Input must be numbers
# Error: Division by zero is not allowed

# %%
# Operations with List of Dictionaries
students = [
    {"id": 1, "name":"Asha", "age":22, "grade": 85},
    {"id": 2, "name":"Brian", "age":21, "grade": 78},
    {"id": 3, "name":"Chloe", "age":23, "grade": 92},
]

#Append to the end
students.append({"id": 4, "name":"Dina", "age":22, "grade": 88})
# print(students)

#Insert at a position
students.insert(1, {"id": 5, "name":"Evan", "age":20, "grade": 81})
# print(students)

# Extend with multiple
students.extend([
    {"id": 6, "name":"Fatma", "age":24, "grade": 90},
    {"id": 7, "name":"Glen", "age":22, "grade": 76},
])
# print(students)

# Remove items (by index or condition)
# removed = students.pop(0)z
# print(removed)

# Remove first matching dic(by equality)
# students.remove( {"id": 2, "name":"Brian", "age":21, "grade": 78})
# print(students)

# Remove by condition (recommended)
# Remove everyone with grade < 80
# student = [s for s in students if s["grade"] >= 80]
# print(student)

# Clear all
# students.clear()
# print(students)


# Update items (edit dictionaries in the list)
for s in students:
    if s["id"] == 3:
        s["grade"] = 95 # overwrite 
        s["status"] = "honours" # add new key
        # or merge many fields:
        s.update ({"age": 24, "comment": "Excellent"})

# print(students)

# Bulk update: add a field to everyone

for s in students:
    s["cohort"] = "2025"

# print(students)

# Safe read/ update  with defaults

for s in students:
    comment = s.get("comment", "none")
    s.setdefault("advisor", "TBD")

# print(students)

# Find first match
target = next((s for s in students if s["name"] == "Chloe"), None)
# print(target)

#Filter a subset
top = [s for s in students if s["grade"] >= 90]
# print(top)

# Transform to a new list (do not mutate original)
names = [s["name"] for s in students]
# print(names)

# print(students)
bumped = [{**s, "grade":s["grade"] +3 } for s in students]
# print(bumped)

# sort (does not copy by default)
students.sort(key = lambda s: s["id"], reverse = True)
# print(students)

# Get a new sorted list (leave original as - is)
sorted_students = sorted(students, key= lambda s:s["name"])
# print(sorted_students)

# Check membership / existence
# Does any student have grade >= 90?
has_top = any(s["grade"] >= 90 for s in students)
# print(has_top)

# Do all students have the 'age' key?
all_have_age = all("age" in s for s in students)
# print(all_have_age)

# Aggregations
avg_grade = (sum(s["grade"] for s in students)) / len(students)
# print(avg_grade)

max_student = max(students, key=lambda s: s["grade"])
# print(max_student)

min_student = min(students, key=lambda s: s["grade"])
# print(min_student)

# Copying (important to avoid accidental linkage)
# shallow copy  of the list (dict still shared)
copy1 = students[:] #slicing
# print(copy1)

copy2 = students.copy()
# print(copy2)
copy3 = list(students)
# print(copy3)b

# Merge dictionaries (python 3.9+)
a = {"id": 10, "name": "Hawa"}
b = {"age": 25, "grade": 91}

merged = a | b
# print(merged)

# In place: 

a |= {"comment": "New"}
print(a)


# Pretting print(for inspection)b
import json
# print(json.dumps(students, indent = 2))

# Exercise
students.append({"id": 8, "name": "Ivy", "age":22, "grade": 83})
# print(students)
students.sort(key=lambda s:s["id"], reverse = False)
# print(students)

# students = [{**s, "grade": s["grade"] + 1000} for s in students]
# print(students)

# students = [s for s in students if s["grade"] > 80]
# print(students)

count = 0
students.sort(key=lambda s:s["grade"], reverse = True)
print(students[:3])
        
    

# Promblem 5: Data Structurs in Python
patient_info = [
    {'ID': 1, 'Name': 'Alice', 'BMI': 22.4}, 
    {'ID': 2, 'Name': 'Bob', 'BMI': 27.1}, 
    {'ID': 3, 'Name': 'Charlie', 'BMI': 24.0}, 
]

patient_info.append({'ID': 4, 'Name': 'Joseph', 'BMI': 30})
# print(patient_info)

# removing id 2
# patient_info = [p for p in patient_info if p['ID'] != 2]
# print(patient_info)

# update the BMI of an existing patient based on the patient ID
for p in patient_info:
    if p['ID'] == 2:
        p['BMI'] = 1028

print(patient_info)

# %%
#Problem 1: Vectorised computation
# Solution for Problem 1
systolic = np.array([120, 130, 110, 140, 135])b
diastolic = np.array([80, 85, 75, 90, 88])

map_values = (systolic + 2*diastolic) / 3
map_values

# Problem 2: Standard Deviation and Mean for Health Metrics (NumPy)
bmi = np.array([22.5, 24.7, 28.1, 30.2, 27.5, 26.1, 23.0])

# find mean
mean_bmi = bmi.mean()
mean_bmi
std_bmi = bmi.std(ddof=1)b

print(f"Mean BMI: {mean_bmi:.2f}")
print(f"Std Dev BMI: {std_bmi:.2f}")
print("Interpreation")
print("- The mean gives the central tendency of BMI in this sample")
print("- The standard deviation indicates how spread out the BMI are around the mean")

# Problem 3: Matrix Multiplication for Health Prediction Models (NumPy)
X = np.array([
    [60, 110, 220],
    [50, 90, 180],
    [70, 130, 210],
    [40, 85, 190]
])

W = np.array([0.5, 0.3, 0.2])
risk_scores = X @ W
risk_scores


# Problem 4: Vectorised Computation in Python (NumPy)
bmi = weight / (height**2)

weights = np.array([70, 85, 90, 60, 75])
heights = np.array ([1.75, 1.80, 1.78, 1.60, 1.70])

bmi_vals = weights / (heights ** 2)
bmi_vals

# %%
#ndarray (Numpy arrays)
a = np.array([[1,2,3],
              [4,5,6]])b
a.shape
a.ndim
a.dtype

# Create arrays quickly
np.array([1,2,3])
np.zeros((2,3))
np.ones((2,3))
np.arange(10)
np.linspace(0,1,10)
np.eye(3)
np.empty((2,3))



x = np.array([1,2,3])
x**2  
np.sqrt(x)


# Indexing and slicing
a = np.arange(10)
part = a[3:7]
part[:] = 99
part

#2D indexing
M = np.arange(12).reshape(3,4)
M
# M[1,2]
M[0:1,1:3]

b = a[3:7].copy()
b

#Boolean masks (filter rows)
x = np.array([])

a = np.array([1,2,3,4,5,6,7,8])
a[a>3] = 0
a

# %%
def calculate_bmi(weight,height):
    return weight / (height**2)

def is_healthy_bmi(bmi):
    if 18.5<= bmi <= 24.9:
        return True
    else:
        return False

# %%
from pathlib import Path
module_code = '''\
def calculate_bmi(weight,height):
    return weight / (height**2)

def is_healthy_bmi(bmi):
    return 18.5<= bmi <= 24.9:
       
'''
Path('health_utils.py').write_text(module_code)

#import and use the module
import importlib
health_utils = importlib.import_module('health_utils')b

bmi_value = health_utils.calculate_bmi(72, 1.78)
bmi_value
print(f"BMI : {bmi_value:.2f}")
print("Health range:", health_utils.is_healthy_bmi(bmi_value))
# Out:
# BMI : 22.72
# Health range: True

# %%
# Problem 7: Statistical Analysis with NumPy

rates = np.array([72, 75, 78, 70, 69, 80, 77, 74, 76, 73])
rates_mean = rates.mean()
rates_mean

rates_median = np.median(rates)
rates_median

rates_std = rates.std(ddof=0)
rates_std

above_one_sd_idx = np.where(rates > rates_mean + rates_std)[0]
above_one_sd_idx
# Out:
# array([2, 5])

# %%
# Problem 8: Boolean and Fancy Indexing with NumPy
glucose = np.array([90, 110, 130, 95, 145, 125, 105])
high_glucose = glucose[glucose > 120]
high_glucose
selected = glucose[[1,3,5]]
selected
# Out:
# array([110,  95, 125])

# %%
# Problem 9: Working with Pandas - Data Cleaning
df9 = pd.DataFrame({
    'Patient ID': [1,2,3,4,5],
    'Age': [45,50, 60,55, 48],
    'Glucose': [105, 98, 110, 95, 115],
    'Cholesterol': [180, np.nan, 200, np.nan, 190]
    
})
df9
print("Missing values (True indcates missing):")
# display(df9.isnull())

chol_mean = df9['Cholesterol'].mean()
chol_mean

df9['Cholesterol'] = df9['Cholesterol'].fillna(chol_mean)
# Out:
# Missing values (True indcates missing):
# np.float64(190.0)

# %%
# Problem 10: Data Analysis with Pandas
df10 = pd.DataFrame({
    'Patient ID': [1,2,3,4,5],
    'Gender': ['Male','Female', 'Male', 'Female', 'Male'],
    'BMI': [25.3, 22.4, 27.5, 23.1, 29.2],
    'Blood Pressure': [120, 110, 130, 115, 140],
    'Cholesterol': [180, 170, 210, 190, 220]      
})

avg_bmi_by_gender = df10.groupby('Gender')['BMI'].mean()
avg_bmi_by_gender
display(avg_bmi_by_gender)

df10['High_Cholesterol'] = df10['Cholesterol'] > 200
display(df10)

out_path = Path('health_summary.csv')
df10.to_csv(out_path, index=False)

print(f"\nSaved DataFrame to {out_path.resolve()}\n")
display(df10)
# Out:
# Gender
# Female    22.750000
# Male      27.333333
# Name: BMI, dtype: float64
#    Patient ID  Gender   BMI  Blood Pressure  Cholesterol  High_Cholesterol
# 0           1    Male  25.3             120          180             False
# 1           2  Female  22.4             110          170             False
# 2           3    Male  27.5             130          210              True
# 3           4  Female  23.1             115          190             False
# 4           5    Male  29.2             140          220              True
# Saved DataFrame to /Users/josephmuganga/Documents/Code/python_programming_for_health_data_science/07.  Week Two Exercise/health_summary.csv
#    Patient ID  Gender   BMI  Blood Pressure  Cholesterol  High_Cholesterol
# 0           1    Male  25.3             120          180             False
# 1           2  Female  22.4             110          170             False
# 2           3    Male  27.5             130          210              True
# ...
